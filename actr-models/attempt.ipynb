# %%
import os.path
import run_model
import actr
actr.load_act_r_model(os.path.abspath("model1.lisp"))
# Out:
# True

# %%
actr.load_act_r_model(os.path.abspath("model1_lf02.lisp"))
run_model.experiment()
# Out:
#    TrialType      BlockType Response     RT
# 0        win  mostly_reward        j  0.895
# 1        win  mostly_reward        j  0.745
# 2        win  mostly_reward        f  0.845
# 3        win  mostly_reward        f  0.745
# 4        win  mostly_reward        f  0.745
# ..       ...            ...      ...    ...
# 59      lose  mostly_punish        f  0.845
# 60      lose  mostly_punish        f  0.745
# 61       win  mostly_punish        f  0.745
# 62   neutral  mostly_punish        f  0.745
# 63       win  mostly_punish        j  0.845
#
# [64 rows x 4 columns]

# %%
actr.load_act_r_model(os.path.abspath("model1_lf20.lisp"))
run_model.experiment()
# Out:
#    TrialType      BlockType Response     RT
# 0        win  mostly_reward        f  1.125
# 1        win  mostly_reward        j  2.241
# 2        win  mostly_reward        f  2.143
# 3        win  mostly_reward        j  2.019
# 4       lose  mostly_reward        f  1.913
# ..       ...            ...      ...    ...
# 59       win  mostly_punish        j  1.050
# 60      lose  mostly_punish        f  1.047
# 61      lose  mostly_punish        j  1.043
# 62   neutral  mostly_punish        j  0.940
# 63       win  mostly_punish        j  0.937
#
# [64 rows x 4 columns]
