# %%
import os.path
import run_model
import actr
actr.load_act_r_model(os.path.abspath("model2.lisp"))
# Out:
# #|Warning: Creating chunk J with no slots |#
# #|Warning: Creating chunk K with no slots |#
# True

# %%
run_model.experiment()
# Out:
# #|Warning: Creating chunk J with no slots |#
# #|Warning: Creating chunk K with no slots |#
#      0.000   GOAL                   SET-BUFFER-CHUNK GOAL GOAL NIL
#      0.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION0 NIL
#      0.050   PROCEDURAL             PRODUCTION-FIRED ATTEND-PROBE
#      0.135   VISION                 SET-BUFFER-CHUNK VISUAL TEXT0
#      0.185   PROCEDURAL             PRODUCTION-FIRED READ-PROBE
#      0.385   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK0
#      0.435   PROCEDURAL             PRODUCTION-FIRED PRESS-MORE
#      0.435   MOTOR                  PUNCH HAND RIGHT FINGER INDEX
#      0.435   VISION                 CLEAR
#      0.635   IMAGINAL               MOD-BUFFER-CHUNK IMAGINAL
# TEST: in respond_to_key_press:  j 645
#      1.185   DECLARATIVE            SET-BUFFER-CHUNK RETRIEVAL WIN-HISTORY-L
#      5.000   ------                 Stopped because time limit reached
# ...
