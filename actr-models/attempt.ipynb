# %%
import os.path
from run_model import *

# %%
load_model("model1")
window = actr.open_exp_window("Gambling Experiment", visible=False)
actr.install_device(window)
do_guess("Reward", window)
# Out:
# ######### LOADED MODEL model1 #########
#      0.000   GOAL                   SET-BUFFER-CHUNK GOAL GOAL NIL
#      0.000   VISION                 SET-BUFFER-CHUNK VISUAL-LOCATION VISUAL-LOCATION0 NIL
#      0.050   PROCEDURAL             PRODUCTION-FIRED ATTEND-PROBE
#      0.135   VISION                 SET-BUFFER-CHUNK VISUAL TEXT0
#      0.185   PROCEDURAL             PRODUCTION-FIRED READ-PROBE
# Chunk NEUTRAL-HISTORY-L does not match
# Chunk NEUTRAL-HISTORY-M does not match
# Chunk LOSE-HISTORY-L does not match
# Chunk LOSE-HISTORY-M does not match
# Chunk WIN-HISTORY-L does not match
# Chunk WIN-HISTORY-M does not match
# No matching chunk found retrieval failure
#      0.385   IMAGINAL               SET-BUFFER-CHUNK IMAGINAL CHUNK0
#      0.435   PROCEDURAL             PRODUCTION-FIRED EVALUATE-MORE
# #|Warning: A retrieval event has been aborted by a new request |#
# Chunk NEUTRAL-HISTORY-L does not match
# Chunk NEUTRAL-HISTORY-M matches
# ...

# %%
experiment("model1")
# Out:
# ######### LOADED MODEL model1 #########
#      TrialType     BlockType Response    RT  BlockTrial  Trial
# 0       Reward  MostlyReward        j   981           0      0
# 1      Neutral  MostlyReward        j  1109           1      1
# 2       Reward  MostlyReward        j  1056           2      2
# 3   Punishment  MostlyReward        j  1066           3      3
# 4       Reward  MostlyReward        j  1088           4      4
# ..         ...           ...      ...   ...         ...    ...
# 59  Punishment  MostlyReward        j  1043           3     59
# 60     Neutral  MostlyReward        j  1044           4     60
# 61      Reward  MostlyReward        j  1036           5     61
# 62     Neutral  MostlyReward        j  1047           6     62
# 63      Reward  MostlyReward        j  1044           7     63
#
# [64 rows x 6 columns]

# %%
actr.dm()
# Out:
# TEXT7-0
#    SCREEN-POS  VISUAL-LOCATION7-0
#    VALUE  "Punishment"
#    COLOR  BLACK
#    HEIGHT  10
#    WIDTH  70
#    TEXT  T
# TEXT3-0
#    SCREEN-POS  VISUAL-LOCATION3-0
#    VALUE  "Neutral"
#    COLOR  BLACK
#    HEIGHT  10
#    WIDTH  49
#    TEXT  T
# TEXT1-0
#    SCREEN-POS  VISUAL-LOCATION1-0
#    VALUE  "Reward"
#    COLOR  BLACK
#    HEIGHT  10
#    WIDTH  42
#    TEXT  T
# TEXT0-0
#    SCREEN-POS  VISUAL-LOCATION0-0
#    VALUE  "?"
#    COLOR  BLACK
#    HEIGHT  10
#    WIDTH  7
#    TEXT  T
# VISUAL-LOCATION7-0
#    KIND  TEXT
#    VALUE  TEXT
#    COLOR  BLACK
#    HEIGHT  10
#    WIDTH  70
#    SCREEN-X  486
#    SCREEN-Y  456
#    DISTANCE  1080
#    SIZE  1.9699999
# VISUAL-LOCATION3-0
#    KIND  TEXT
#    VALUE  TEXT
#    COLOR  BLACK
#    HEIGHT  10
#    WIDTH  49
#    SCREEN-X  475
#    SCREEN-Y  456
#    DISTANCE  1080
#    SIZE  1.38
# VISUAL-LOCATION1-0
#    KIND  TEXT
#    VALUE  TEXT
#    COLOR  BLACK
#    HEIGHT  10
#    WIDTH  42
#    SCREEN-X  472
# ...

# %%
T = create_stimuli()
do_experiment(T)
# Out:
# [('Reward', 'MostlyReward', '', -1288997),
#  ('Reward', 'MostlyReward', '', -1298997),
#  ('Reward', 'MostlyReward', '', -1308997),
#  ('Reward', 'MostlyReward', '', -1318997),
#  ('Reward', 'MostlyReward', '', -1328997),
#  ('Reward', 'MostlyReward', '', -1338997),
#  ('Punishment', 'MostlyReward', '', -1348997),
#  ('Neutral', 'MostlyReward', '', -1358997),
#  ('Reward', 'MostlyReward', '', -1368997),
#  ('Neutral', 'MostlyReward', '', -1378997),
#  ('Reward', 'MostlyReward', '', -1388997),
#  ('Neutral', 'MostlyReward', '', -1398997),
#  ('Reward', 'MostlyReward', '', -1408997),
#  ('Punishment', 'MostlyReward', '', -1418997),
#  ('Reward', 'MostlyReward', '', -1428997),
#  ('Punishment', 'MostlyReward', '', -1438997),
#  ('Punishment', 'MostlyPunishment', '', -1448997),
#  ('Reward', 'MostlyPunishment', '', -1458997),
#  ('Punishment', 'MostlyPunishment', '', -1468997),
#  ('Punishment', 'MostlyPunishment', '', -1478997),
#  ('Punishment', 'MostlyPunishment', '', -1488997),
# ...
